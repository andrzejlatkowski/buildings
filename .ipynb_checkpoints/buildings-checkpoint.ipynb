# %%
#|default_exp buildings

# %%
#|export
from fastai.vision.all import *
import gradio as gr

# %%
im = PILImage.create('tenement.jpg')
im.thumbnail((192, 192))
im
# Out:
# PILImage mode=RGB size=187x192

# %%
#|export
learn = load_learner('model.pkl')

# %%
# %time learn.predict(im)
# Out:
# CPU times: user 208 ms, sys: 70 ms, total: 278 ms
# Wall time: 248 ms
# ('kamienica front warszawa', tensor(1), tensor([0.0014, 0.9986]))

# %%
#|export
categories = ('Block', 'Tenement')

def classify_image(img):
    pred,idx,probs = learn.predict(img)
    return dict(zip(categories, map(float, probs)))

# %%
classify_image(im)
# Out:
# {'Block': 0.0014157223049551249, 'Tenement': 0.9985842704772949}

# %%
#|export
image = gr.Image(height=512, width=512)
label = gr.Label()
examples = ['block.jpg', 'tenement.jpg']

intf = gr.Interface(fn=classify_image, inputs=image, outputs=label, examples=examples)
intf.launch(inline=False)
# Out:
# /Users/andrzej/miniforge3/envs/snakes/lib/python3.9/site-packages/gradio/deprecation.py:40: UserWarning: `width` is deprecated in `Interface()`, please use it within `launch()` instead.
#   warnings.warn(value)
# /Users/andrzej/miniforge3/envs/snakes/lib/python3.9/site-packages/gradio/deprecation.py:40: UserWarning: `height` is deprecated in `Interface()`, please use it within `launch()` instead.
#   warnings.warn(value)
# Running on local URL:  http://127.0.0.1:7864
#
# To create a public link, set `share=True` in `launch()`.

# %%
# import nbdev
# nbdev.export.nb_export('buildings.ipynb', './')
# print('Export successful')
import nbdev
nbdev.export.nb_export('buildings.ipynb', './')
print('Export successful')
# Out:
# Export successful
